# %%
import bz2
import json
import pickle

import numpy
import pandas
import ipywidgets
import IPython.display
import sklearn.decomposition
import scipy.cluster.hierarchy
import matplotlib.pyplot as plt

import raha

# %%
app_1 = raha.Detection()
app_2 = raha.Correction()

# How many tuples would you label?
app_1.LABELING_BUDGET = 20
app_2.LABELING_BUDGET = 0

# Would you like to see the logs?
app_1.VERBOSE = True
app_2.VERBOSE = True

# Do you want to filter out ineffective error detector startegies?
app_1.STRATEGY_FILTERING = True
app_1.HISTORICAL_DATASETS = [
    {
        "name": "compass",
        "path": "data/compass/dirty_1.csv",
        "clean_path": "data/compass/clean_1.csv"
    },
    # {
    #     "name": "beers",
    #     "path": "../datasets/beers/dirty.csv",
    #     "clean_path": "../datasets/beers/clean.csv"
    # }
]

# Do you have any pretrained error corrector models to load?
# PRETRAINED_VALUE_BASED_MODELS_PATH = "../supplementaries/models/pretrained_value_based_models.dictionary"
# pretrained_models = pickle.load(bz2.BZ2File(PRETRAINED_VALUE_BASED_MODELS_PATH, "rb"))

# %%
dataset_dictionary = {
    "name": "compass",
    "path": "data/compass/dirty_1.csv",
    "clean_path": "data/compass/clean_1.csv"
}
d = app_1.initialize_dataset(dataset_dictionary)
d.dataframe.head()
# Out:
#    id                name    first         last compas_screening_date     sex  \
# 0   3         kevon dixon    kevon        dixon            2013-01-27    Male
# 1   4            ed philo       ed        philo            2013-04-14    Male
# 2   5         marcu brown    marcu        brown            2013-01-13    Male
# 3   6  bouthy pierrelouis   bouthy  pierrelouis            2013-03-26    Male
# 4  16     kortney coleman  kortney      coleman            2013-01-01  Female
#
#           dob age       age_cat              race  ... vr_offense_date  \
# 0  1982-01-22  34       25 - 45  African-American  ...      2013-07-05
# 1  1991-05-14  24  Less than 25  African-American  ...
# 2  1993-01-21  23  Less than 25  African-American  ...
# 3  1973-01-22  43       25 - 45             Other  ...
# 4  1978-08-22  37       25 - 45         Caucasian  ...
#
#                 vr_charge_desc v_type_of_assessment v_decile_score  \
# 0  Felony Battery (Dom Strang)     Risk of Violence              1
# 1                                  Risk of Violence              3
# 2                                  Risk of Violence              6
# 3                                  Risk of Violence              1
# 4                                  Risk of Violence              1
#
#   v_score_text v_screening_date  type_of_assessment decile_score.1 score_text  \
# 0          Low       2013-01-27  Risk of Recidivism              3        Low
# 1          Low       2013-04-14  Risk of Recidivism              4        Low
# 2       Medium       2013-01-13  Risk of Recidivism              8       High
# 3          Low       2013-03-26  Risk of Recidivism              1        Low
# 4          Low       2013-01-01  Risk of Recidivism              1        Low
#
#   screening_date
# 0     2013-01-27
# 1     2013-04-14
# 2     2013-01-13
# 3     2013-03-26
# 4     2013-01-01
#
# [5 rows x 47 columns]

# %%
app_1.run_strategies(d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 app_1.run_strategies(d)
#
# File ~/Source/cse841-project/venv/lib/python3.11/site-packages/raha/detection.py:195, in Detection.run_strategies(self, d)
#     193     for dd in self.HISTORICAL_DATASETS + [d.dictionary]:
#     194         raha.utilities.dataset_profiler(dd)
# --> 195         raha.utilities.evaluation_profiler(dd)
#     196     strategy_profiles_list = raha.utilities.get_selected_strategies_via_historical_data(d.dictionary, self.HISTORICAL_DATASETS)
#     197 d.strategy_profiles = strategy_profiles_list
#
# File ~/Source/cse841-project/venv/lib/python3.11/site-packages/raha/utilities.py:94, in evaluation_profiler(dataset_dictionary)
#      92 sp_folder_path = os.path.join(d.results_folder, "strategy-profiling")
#      93 columns_performance = {j: {} for j in range(d.dataframe.shape[1])}
# ---> 94 strategies_file_list = os.listdir(sp_folder_path)
#      95 for strategy_file in strategies_file_list:
#      96     strategy_profile = pickle.load(open(os.path.join(sp_folder_path, strategy_file), "rb"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/compass/raha-baran-results-compass/strategy-profiling'
