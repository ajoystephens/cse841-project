# %%
import numpy as np

import raha
import pickle

# %%
path = 'datasets/compas/raha-baran-results-compas/error-correction/correction.dataset'

# %%
objects = []
with (open(path, "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break
data = objects[0]

# %%
data.get_actual_errors_dictionary()
correction_dict = data.corrected_cells
# data.get_correction_dictionary()

# %%
data.create_repaired_dataset(correction_dict)
data.repaired_dataframe
# Out:
#          id                  name        first            last  \
# 0         3           kevon dixon        kevon           dixon
# 1         4              ed philo           ed           philo
# 2         5           marcu brown        marcu           brown
# 3         6    bouthy pierrelouis       bouthy     pierrelouis
# 4        16       kortney coleman      kortney         coleman
# ...     ...                   ...          ...             ...
# 3345  11741  edwin moralesherrera        edwin  moralesherrera
# 3346  11746    dashawniese rainey  dashawniese          rainey
# 3347  11747          martin davis       martin           davis
# 3348  11752      rodrick phillips      rodrick        phillips
# 3349  11754     raymond hernandez      raymond       hernandez
#
#      compas_screening_date     sex         dob age          age_cat  \
# 0               2013-01-27    Male  1982-01-22  34          25 - 45
# 1               2013-04-14    Male  1991-05-14  24     Less than 25
# ...

# %%
data.dataframe
# Out:
#          id                  name        first            last  \
# 0         3           kevon dixon        kevon           dixon
# 1         4              ed philo           ed           philo
# 2         5           marcu brown        marcu           brown
# 3         6    bouthy pierrelouis       bouthy     pierrelouis
# 4        16       kortney coleman      kortney         coleman
# ...     ...                   ...          ...             ...
# 3345  11741  edwin moralesherrera        edwin  moralesherrera
# 3346  11746    dashawniese rainey  dashawniese          rainey
# 3347  11747          martin davis       martin           davis
# 3348  11752      rodrick phillips      rodrick        phillips
# 3349  11754     raymond hernandez      raymond       hernandez
#
#      compas_screening_date     sex         dob age          age_cat  \
# 0               2013-01-27    Male  1982-01-22  34          25 - 45
# 1               2013-04-14    Male  1991-05-14  24     Less than 25
# ...
